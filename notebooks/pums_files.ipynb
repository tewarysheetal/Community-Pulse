# %%
import pandas as pd
from pathlib import Path
import re

# %%
base_dir = Path(r"D:\Projects\Community-Pulse\data")
pums_dir=base_dir / "pums"
# Out:
# D:\Projects\Community-Pulse\data\pums

# %%
for year_dir in sorted(pums_dir.iterdir()):
    for csv_file in sorted(year_dir.glob("*.csv")):
        df = pd.read_csv(csv_file, nrows=0)
        print(f"{year_dir.name} | {csv_file.name}")
        print(df.columns.tolist())
        print()
# Out:
# 2019 | housing.csv
# ...
